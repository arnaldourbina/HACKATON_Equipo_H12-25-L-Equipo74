# %% [markdown]
# <a href="https://colab.research.google.com/github/arnaldourbina/HACKATON_Equipo_H12-25-L-Equipo74/blob/feature-preliminar%2FCarga_Limpieza_csv/Desarrollo_Carga_y_Limpieza_P3_FoT(Preliminar/No_Oficial).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📚 | Importe de las librerias necesarias.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 📘 | Diccionario de Datos pre-limpieza
#
# | **Nombre**               | **Descripción**                                                        |
# |--------------------------|------------------------------------------------------------------------|
# | `year`              | El año en el que tuvo lugar el vuelo.                         |
# | `month`                   | El mes en el que tuvo lugar el vuelo (1 a 12).                                    |
# | `day`                  | El día del mes en el que tuvo lugar el vuelo (1 a 31).                                         |
# | `dep_time`           | La hora real local de salida del vuelo, en formato de 24 horas (hhmm).                   |
# | `sched_dep_time`                 | La hora local programada de salida del vuelo, en formato de 24 horas (hhmm).                                   |
# | `dep_delay`              | La diferencia entre la hora real y la hora programada de salida del vuelo, en minutos.                                 |
# | `arr_time`                  | La hora real local de llegada del vuelo, en formato de 24 horas (hhmm).                                         |
# | `sched_arr_time`            | La hora local programada de llegada del vuelo, en formato de 24 horas (hhmm).                                    |
# | `arr_delay`           | La diferencia entre la hora real y la hora programada de llegada del vuelo, en minutos. Un valor positivo indica un retraso en la llegada.                             |
# | `carrier`         | Código de la aerolínea que opera el vuelo, usualmente de dos letras.                                |
# | `flight`          | Número de vuelo asignado por la aerolínea para identificar la ruta específica.                           |
# | `tailnum`            | Matrícula única del avión, identificador físico de la aeronave.                            |
# | `origin`        | Código de tres letras del aeropuerto de salida del vuelo.                   |
# | `dest`             | Código de tres letras del aeropuerto de llegada del vuelo.     |
# | `air_time`             | Tiempo efectivo de vuelo en minutos, desde despegue hasta aterrizaje.                                   |
# | `distance`         | Distancia aproximada entre aeropuertos de origen y destino, generalmente en millas.                                 |
# | `hour`                | Hora programada de salida del vuelo, en formato 00–23.                                                      |
# | `minute`        | Minuto programado de salida complementando la hora de despegue.                    |
# | `time_hour`           | Fecha y hora combinadas del vuelo, normalmente redondeadas a la hora.                                                         |
# | `name`         | Nombre descriptivo del aeropuerto.                      |

# %% [markdown]
# # 🔎 | Carga y exploración preliminar de los datos.

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/flights.csv", index_col=0)

# %% [markdown]
# ### Explora una selección aleatoria del banco de datos.

# %%
df.sample(10)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# id
# 272600  2013      7   24    1348.0            1355       -7.0    1546.0
# 78160   2013     11   25     712.0             715       -3.0     941.0
# 235318  2013      6   14    2312.0            2000      192.0      30.0
# 123977  2013      2   15    1341.0            1345       -4.0    1626.0
# 82650   2013     11   30    1237.0            1215       22.0    1341.0
# 255933  2013      7    7     915.0             915        0.0    1154.0
# 110071  2013     12   30    1453.0            1500       -7.0    1717.0
# 242632  2013      6   22    1736.0            1725       11.0    2006.0
# 241354  2013      6   21    1049.0            1055       -6.0    1335.0
# 150080  2013      3   15    1817.0            1820       -3.0    2021.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# id
# 272600            1550       -4.0      MQ    3567  N509MQ    LGA  CLT
# 78160              950       -9.0      MQ    3547  N849MQ    LGA  XNA
# 235318            2140      170.0      MQ    3591  N724MQ    LGA  RDU
# 123977            1655      -29.0      B6     209  N805JB    JFK  LGB
# 82650             1333        8.0      EV    4214  N19554    EWR  BUF
# 255933            1215      -21.0      VX     161  N837VA    EWR  LAX
# 110071            1740      -23.0      MQ    3202  N643MQ    JFK  IND
# 242632            2024      -18.0      UA    1001  N38459    EWR  PBI
# 241354            1411      -36.0      DL    1903  N333NB    LGA  SRQ
# 150080            2005       16.0      AA     353  N3CXAA    LGA  ORD
#
#         air_time  distance  hour  minute            time_hour  \
# id
# 272600      81.0       544    13      55  2013-07-24 13:00:00
# 78160      190.0      1147     7      15  2013-11-25 07:00:00
# 235318      61.0       431    20       0  2013-06-14 20:00:00
# 123977     329.0      2465    13      45  2013-02-15 13:00:00
# 82650       49.0       282    12      15  2013-11-30 12:00:00
# 255933     310.0      2454     9      15  2013-07-07 09:00:00
# 110071     121.0       665    15       0  2013-12-30 15:00:00
# 242632     134.0      1023    17      25  2013-06-22 17:00:00
# 241354     143.0      1047    10      55  2013-06-21 10:00:00
# 150080     156.0       733    18      20  2013-03-15 18:00:00
#
#                             name
# id
# 272600                 Envoy Air
# 78160                  Envoy Air
# 235318                 Envoy Air
# 123977           JetBlue Airways
# 82650   ExpressJet Airlines Inc.
# 255933            Virgin America
# 110071                 Envoy Air
# 242632     United Air Lines Inc.
# 241354      Delta Air Lines Inc.
# 150080    American Airlines Inc.

# %% [markdown]
# ### Explora la cantidad de columnas que existen y sus nombres.

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'name'],
#       dtype='object')

# %% [markdown]
# ### Imprime el tipo de dato por columna.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336776 entries, 0 to 336775
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
#  16  hour            336776 non-null  int64
#  17  minute          336776 non-null  int64
#  18  time_hour       336776 non-null  object
#  19  name            336776 non-null  object
# dtypes: float64(5), int64(9), object(6)
# memory usage: 54.0+ MB

# %% [markdown]
# ### Imprime por pantalla
#
# Mostramos los valores matematicos de las columnas, junto con sus sus rangos (buscando encontrar valores imposibles).

# %%
df.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# min       -43.000000       1.000000        1.000000     -86.000000
# 25%        -5.000000    1104.000000     1124.000000     -17.000000
# 50%        -2.000000    1535.000000     1556.000000      -5.000000
# 75%        11.000000    1940.000000     1945.000000      14.000000
# max      1301.000000    2400.000000     2359.000000    1272.000000
#
#               flight       air_time       distance           hour  \
# count  336776.000000  327346.000000  336776.000000  336776.000000
# mean     1971.923620     150.686460    1039.912604      13.180247
# std      1632.471938      93.688305     733.233033       4.661316
# min         1.000000      20.000000      17.000000       1.000000
# 25%       553.000000      82.000000     502.000000       9.000000
# 50%      1496.000000     129.000000     872.000000      13.000000
# 75%      3465.000000     192.000000    1389.000000      17.000000
# max      8500.000000     695.000000    4983.000000      23.000000
#
#               minute
# count  336776.000000
# mean       26.230100
# std        19.300846
# min         0.000000
# 25%         8.000000
# 50%        29.000000
# 75%        44.000000
# max        59.000000

# %% [markdown]
# ### Conteo de la cantidad de nulos que existen por columna.

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# air_time          9430
# arr_delay         9430
# arr_time          8713
# dep_time          8255
# dep_delay         8255
# tailnum           2512
# year                 0
# month                0
# day                  0
# sched_arr_time       0
# carrier              0
# sched_dep_time       0
# flight               0
# origin               0
# dest                 0
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %% [markdown]
# # 🧹 | Proceso de limpieza de los datos.

# %%
# Creamos una copia del DataFrame en caso de cualquier problema.
df_copia = df.copy()

# %%
df_copia.head(10)
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# id
# 0   2013      1    1     517.0             515        2.0     830.0
# 1   2013      1    1     533.0             529        4.0     850.0
# 2   2013      1    1     542.0             540        2.0     923.0
# 3   2013      1    1     544.0             545       -1.0    1004.0
# 4   2013      1    1     554.0             600       -6.0     812.0
# 5   2013      1    1     554.0             558       -4.0     740.0
# 6   2013      1    1     555.0             600       -5.0     913.0
# 7   2013      1    1     557.0             600       -3.0     709.0
# 8   2013      1    1     557.0             600       -3.0     838.0
# 9   2013      1    1     558.0             600       -2.0     753.0
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# id
# 0              819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1              830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2              850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3             1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4              837      -25.0      DL     461  N668DN    LGA  ATL     116.0
# 5              728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 6              854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 7              723      -14.0      EV    5708  N829AS    LGA  IAD      53.0
# 8              846       -8.0      B6      79  N593JB    JFK  MCO     140.0
# 9              745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
#
#     distance  hour  minute            time_hour                      name
# id
# 0       1400     5      15  2013-01-01 05:00:00     United Air Lines Inc.
# 1       1416     5      29  2013-01-01 05:00:00     United Air Lines Inc.
# 2       1089     5      40  2013-01-01 05:00:00    American Airlines Inc.
# 3       1576     5      45  2013-01-01 05:00:00           JetBlue Airways
# 4        762     6       0  2013-01-01 06:00:00      Delta Air Lines Inc.
# 5        719     5      58  2013-01-01 05:00:00     United Air Lines Inc.
# 6       1065     6       0  2013-01-01 06:00:00           JetBlue Airways
# 7        229     6       0  2013-01-01 06:00:00  ExpressJet Airlines Inc.
# 8        944     6       0  2013-01-01 06:00:00           JetBlue Airways
# 9        733     6       0  2013-01-01 06:00:00    American Airlines Inc.

# %% [markdown]
# ### Explicación y justificación valores nulos.
#
# Se eliminan los valores nulos de las columnas sin información critica para nuestro modelo.
#
# Aqui se decidió eliminar los datos nulos de estas columnas ya que rellenar estos valores nulos con la media, moda u otras opciones, sería contraproducente para nuestro modelo pues este aprendería patrones inexistentes.

# %%
cols_criticas = ["dep_delay", "time_hour", "carrier", "origin", "dest", "distance"]
df_copia = df_copia.dropna(subset=cols_criticas)

# %%
df_copia.tail(5)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# id
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# id
# 336765            2351      -17.0      B6    1816  N354JB    JFK  SYR
# 336766               7      -20.0      B6    2002  N281JB    JFK  BUF
# 336767               1      -16.0      B6     486  N346JB    JFK  ROC
# 336768            2358        1.0      B6     718  N565JB    JFK  BOS
# 336769             350      -25.0      B6     745  N516JB    JFK  PSE
#
#         air_time  distance  hour  minute            time_hour             name
# id
# 336765      41.0       209    22      45  2013-09-30 22:00:00  JetBlue Airways
# 336766      52.0       301    22      50  2013-09-30 22:00:00  JetBlue Airways
# 336767      47.0       264    22      46  2013-09-30 22:00:00  JetBlue Airways
# 336768      33.0       187    22      55  2013-09-30 22:00:00  JetBlue Airways
# 336769     196.0      1617    23      59  2013-09-30 23:00:00  JetBlue Airways

# %% [markdown]
# ### Verificación valores nulos

# %%
df_copia.isnull().sum().sort_values(ascending=False)
# Out:
# air_time          1175
# arr_delay         1175
# arr_time           458
# year                 0
# dep_time             0
# day                  0
# month                0
# dep_delay            0
# sched_arr_time       0
# carrier              0
# flight               0
# sched_dep_time       0
# tailnum              0
# origin               0
# dest                 0
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %% [markdown]
# ### Explicación columna_fecha_hora_partida
#
# A partir de time_hour creamos la columna fecha y hora de partida con su tipo de dato correspondiente. Seguidamente eliminamos la columna time_hour ya que su tipo de dato es object y tiene información repetida.

# %%
df_copia["fecha_hora_partida"] = pd.to_datetime(df["time_hour"])

# %%
df_copia = df_copia.drop(columns=["time_hour"])

# %% [markdown]
# ### Explicación columna target
#
# Creamos la columna target para entrenamiento del modelo. Ademas decidimos con el equipo que el tiempo maximo para considerar un vuelo atrasado será de 15 minutos.

# %% [markdown]
# ### Explicación columna dep_delay
# Se utiliza la columna dep_delay ya que es la columna que nos indica el retraso de salida de un vuelo lo cual es lo que pidió el cliente.
#
# Ejecutando esta acción creamos una columna con datos binarios perfecta para ser utilizada en el modelo predictivo.

# %% [markdown]
# # ⚠ | Explicación variable target 0 y 1

# %% [markdown]
# ### Mayor o igual a 15 minutos ( >= 15 ) = 1
# ### Menor a 15 minutos ( < 15 ) = 0

# %%
retraso = 15
df_copia["target"] = (df_copia["dep_delay"] >= retraso).astype(int)

# %%
df_copia.head(5)
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# id
# 0   2013      1    1     517.0             515        2.0     830.0
# 1   2013      1    1     533.0             529        4.0     850.0
# 2   2013      1    1     542.0             540        2.0     923.0
# 3   2013      1    1     544.0             545       -1.0    1004.0
# 4   2013      1    1     554.0             600       -6.0     812.0
#
#     sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# id                                     ...
# 0              819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1              830       20.0      UA  ...   N24211    LGA  IAH    227.0
# 2              850       33.0      AA  ...   N619AA    JFK  MIA    160.0
# 3             1022      -18.0      B6  ...   N804JB    JFK  BQN    183.0
# 4              837      -25.0      DL  ...   N668DN    LGA  ATL    116.0
#
#     distance  hour  minute                    name  fecha_hora_partida target
# id
# 0       1400     5      15   United Air Lines Inc. 2013-01-01 05:00:00      0
# 1       1416     5      29   United Air Lines Inc. 2013-01-01 05:00:00      0
# 2       1089     5      40  American Airlines Inc. 2013-01-01 05:00:00      0
# 3       1576     5      45         JetBlue Airways 2013-01-01 05:00:00      0
# 4        762     6       0    Delta Air Lines Inc. 2013-01-01 06:00:00      0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Tratamiento de Outliers

# %% [markdown]
# ### Resultados de Outliers
#
# Observamos que en distance hay un minimo de 80¿Km o millas? y un maximo de 4983¿Km o millas? lo cual es coherente con los datos.
# En cuanto a dep_delay, todo se encuentra dentro de un rango razonable a excepción de retrasos extremos que contemplan 1301 minutos.

# %%
df_copia[["distance", "dep_delay"]].describe()
# Out:
#             distance      dep_delay
# count  328521.000000  328521.000000
# mean     1048.570600      12.639070
# std       735.908891      40.210061
# min        80.000000     -43.000000
# 25%       509.000000      -5.000000
# 50%       888.000000      -2.000000
# 75%      1389.000000      11.000000
# max      4983.000000    1301.000000

# %% [markdown]
# De manera preventiva se eliminan la distancia en 0. La cual significaría que un vuelo NO despegó pero se encuentra en el dataset.

# %%
df_copia = df_copia[df_copia["distance"] > 0]

# %% [markdown]
# ### Creación de variables de tiempo.
#
# Creamos variables de tiempo derivadas de fecha y hora de partida.
#
# Dia de semana donde 0 = lunes y 6 = domingo

# %%
df_copia["hora_salida"] = df_copia["fecha_hora_partida"].dt.hour
df_copia["dia_semana"] = df_copia["fecha_hora_partida"].dt.dayofweek  # 0 = lunes
df_copia["mes"] = df_copia["fecha_hora_partida"].dt.month

# %%
df_copia.head(5)
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# id
# 0   2013      1    1     517.0             515        2.0     830.0
# 1   2013      1    1     533.0             529        4.0     850.0
# 2   2013      1    1     542.0             540        2.0     923.0
# 3   2013      1    1     544.0             545       -1.0    1004.0
# 4   2013      1    1     554.0             600       -6.0     812.0
#
#     sched_arr_time  arr_delay carrier  ...  air_time distance hour minute  \
# id                                     ...
# 0              819       11.0      UA  ...     227.0     1400    5     15
# 1              830       20.0      UA  ...     227.0     1416    5     29
# 2              850       33.0      AA  ...     160.0     1089    5     40
# 3             1022      -18.0      B6  ...     183.0     1576    5     45
# 4              837      -25.0      DL  ...     116.0      762    6      0
#
#                       name  fecha_hora_partida  target  hora_salida  \
# id
# 0    United Air Lines Inc. 2013-01-01 05:00:00       0            5
# 1    United Air Lines Inc. 2013-01-01 05:00:00       0            5
# 2   American Airlines Inc. 2013-01-01 05:00:00       0            5
# 3          JetBlue Airways 2013-01-01 05:00:00       0            5
# 4     Delta Air Lines Inc. 2013-01-01 06:00:00       0            6
#
#    dia_semana mes
# id
# 0           1   1
# 1           1   1
# 2           1   1
# 3           1   1
# 4           1   1
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Definimos la franja horaria de salida.

# %%
def franja_horaria(hora):
    if hora < 5 or hora >= 22:
        return "noche"
    elif hora < 12:
        return "mañana"
    else:
        return "tarde"

df_copia["franja_horaria"] = df_copia["hora_salida"].apply(franja_horaria)

# %%
df_copia.sample(10)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# id
# 243102  2013      6   23    1055.0            1106      -11.0    1149.0
# 170915  2013      4    7     834.0             839       -5.0     931.0
# 14105   2013      1   17     717.0             715        2.0    1011.0
# 252785  2013      7    3    1249.0            1300      -11.0    1500.0
# 240615  2013      6   20    1536.0            1529        7.0    1737.0
# 238581  2013      6   18    1503.0            1505       -2.0    1924.0
# 111754  2013      2    1    1412.0            1415       -3.0    1620.0
# 314833  2013      9    7     822.0             829       -7.0     955.0
# 35334   2013     10    9    1927.0            1930       -3.0    2217.0
# 279479  2013      7   31    1547.0            1550       -3.0    1752.0
#
#         sched_arr_time  arr_delay carrier  ...  distance hour minute  \
# id                                         ...
# 243102            1209      -20.0      EV  ...       160   11      6
# 170915             950      -19.0      B6  ...       200    8     39
# 14105             1027      -16.0      UA  ...      1068    7     15
# 252785            1505       -5.0      MQ  ...       502   13      0
# 240615            1800      -23.0      UA  ...      1605   15     29
# 238581            1835       49.0      AA  ...      1089   15      5
# 111754            1638      -18.0      DL  ...       746   14     15
# 314833            1017      -22.0      DL  ...      1008    8     29
# 35334             2233      -16.0      UA  ...       997   19     30
# 279479            1752        0.0      EV  ...       569   15     50
#
#                             name  fecha_hora_partida  target  hora_salida  \
# id
# 243102  ExpressJet Airlines Inc. 2013-06-23 11:00:00       0           11
# 170915           JetBlue Airways 2013-04-07 08:00:00       0            8
# 14105      United Air Lines Inc. 2013-01-17 07:00:00       0            7
# 252785                 Envoy Air 2013-07-03 13:00:00       0           13
# 240615     United Air Lines Inc. 2013-06-20 15:00:00       0           15
# 238581    American Airlines Inc. 2013-06-18 15:00:00       0           15
# 111754      Delta Air Lines Inc. 2013-02-01 14:00:00       0           14
# 314833      Delta Air Lines Inc. 2013-09-07 08:00:00       0            8
# 35334      United Air Lines Inc. 2013-10-09 19:00:00       0           19
# 279479  ExpressJet Airlines Inc. 2013-07-31 15:00:00       0           15
#
#         dia_semana mes franja_horaria
# id
# 243102           6   6         mañana
# 170915           6   4         mañana
# 14105            3   1         mañana
# 252785           2   7          tarde
# 240615           3   6          tarde
# 238581           1   6          tarde
# 111754           4   2          tarde
# 314833           5   9         mañana
# 35334            2  10          tarde
# 279479           2   7          tarde
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Se eliminan las columnas que generan redundancia.
#
# Se eliminan estas columnas ya que la información que contienen ya está representada en las columnas creadas fecha_hora_partida, hora_salida, dia_semana, mes y franja horaria. Si no se eliminan corremos el riesgo de tener valores duplicados confundiendo al modelo final.

# %%
df_copia = df_copia.drop(columns=["year", "month", "day", "hour", "minute"])

# %%
df_copia.columns
# Out:
# Index(['dep_time', 'sched_dep_time', 'dep_delay', 'arr_time', 'sched_arr_time',
#        'arr_delay', 'carrier', 'flight', 'tailnum', 'origin', 'dest',
#        'air_time', 'distance', 'name', 'fecha_hora_partida', 'target',
#        'hora_salida', 'dia_semana', 'mes', 'franja_horaria'],
#       dtype='object')

# %% [markdown]
# # 🧭 | Mapeo de las columnas segun contrato (DS-Backend)
#
# Se definió que la data a utilizar será:
#
# - aerolinea
# - origen
# - destino
# - fecha_partida
# - distancia_km

# %%
df_copia["aerolinea"] = df_copia["carrier"]
df_copia["origen"] = df_copia["origin"]
df_copia["destino"] = df_copia["dest"]
df_copia["distancia_km"] = df_copia["distance"] * 1.60934  # transformamos millas a kilometros.

# %% [markdown]
# ### Explicación eliminación de columnas con información poco relevante.
#
# Dentro de este set de columnas, existen aquellas que contienen información del futuro las cuales no tienen relevancia para predecir el retraso de despegue de un vuelo. Estas columnas contienen data que el modelo no conoce antes del vuelo.
#
# Otras columnas tienen data poco util o que ya se encuentran representadas por columnas creadas anteriormente.

# %%
df_copia = df_copia.drop(columns=["arr_time", "sched_arr_time", "arr_delay","air_time", "flight", "tailnum", "name","sched_dep_time", "dep_time"])
df_copia.tail(10)
# Out:
#         dep_delay carrier origin dest  distance  fecha_hora_partida  target  \
# id
# 336760       72.0      EV    EWR  STL       872 2013-09-30 20:00:00       1
# 336761      -14.0      B6    JFK  PWM       273 2013-09-30 22:00:00       0
# 336762       80.0      UA    EWR  SFO      2565 2013-09-30 21:00:00       1
# 336763      154.0      B6    JFK  MCO       944 2013-09-30 20:00:00       1
# 336764       -8.0      B6    JFK  BTV       266 2013-09-30 22:00:00       0
# 336765       -5.0      B6    JFK  SYR       209 2013-09-30 22:00:00       0
# 336766      -10.0      B6    JFK  BUF       301 2013-09-30 22:00:00       0
# 336767       -5.0      B6    JFK  ROC       264 2013-09-30 22:00:00       0
# 336768       12.0      B6    JFK  BOS       187 2013-09-30 22:00:00       0
# 336769      -10.0      B6    JFK  PSE      1617 2013-09-30 23:00:00       0
#
#         hora_salida  dia_semana  mes franja_horaria aerolinea origen destino  \
# id
# 336760           20           0    9          tarde        EV    EWR     STL
# 336761           22           0    9          noche        B6    JFK     PWM
# 336762           21           0    9          tarde        UA    EWR     SFO
# 336763           20           0    9          tarde        B6    JFK     MCO
# 336764           22           0    9          noche        B6    JFK     BTV
# 336765           22           0    9          noche        B6    JFK     SYR
# 336766           22           0    9          noche        B6    JFK     BUF
# 336767           22           0    9          noche        B6    JFK     ROC
# 336768           22           0    9          noche        B6    JFK     BOS
# 336769           23           0    9          noche        B6    JFK     PSE
#
#         distancia_km
# id
# 336760    1403.34448
# 336761     439.34982
# 336762    4127.95710
# 336763    1519.21696
# 336764     428.08444
# 336765     336.35206
# 336766     484.41134
# 336767     424.86576
# 336768     300.94658
# 336769    2602.30278

# %% [markdown]
# ### Chequeo de distribución del target.
#
# Observamos que se encuentra presente la variable 0 (**Puntual**) mas veces que la variable 1 (**Retrasado**). Lo que nos quiere decir que el conjunto de datos está desbalanceado.

# %%
df_copia["target"].value_counts(normalize=True)
df_copia["target"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ### Renombre de las columnas.
#
# Se cambian los nombres de aquellas columnas en ingles a su igual en español.

# %%
df_copia = df_copia.rename(columns={
    "dep_delay": "retraso_salida_min",
    "carrier": "aerolinea",
    "origin": "origen",
    "dest": "destino",
    "distance": "distancia_millas"
})

df_copia["distancia_km"] = df_copia["distancia_millas"] * 1.60934

# %%
df_copia.head(10)
# Out:
#     retraso_salida_min aerolinea origen destino  distancia_millas  \
# id
# 0                  2.0        UA    EWR     IAH              1400
# 1                  4.0        UA    LGA     IAH              1416
# 2                  2.0        AA    JFK     MIA              1089
# 3                 -1.0        B6    JFK     BQN              1576
# 4                 -6.0        DL    LGA     ATL               762
# 5                 -4.0        UA    EWR     ORD               719
# 6                 -5.0        B6    EWR     FLL              1065
# 7                 -3.0        EV    LGA     IAD               229
# 8                 -3.0        B6    JFK     MCO               944
# 9                 -2.0        AA    LGA     ORD               733
#
#     fecha_hora_partida  target  hora_salida  dia_semana  mes franja_horaria  \
# id
# 0  2013-01-01 05:00:00       0            5           1    1         mañana
# 1  2013-01-01 05:00:00       0            5           1    1         mañana
# 2  2013-01-01 05:00:00       0            5           1    1         mañana
# 3  2013-01-01 05:00:00       0            5           1    1         mañana
# 4  2013-01-01 06:00:00       0            6           1    1         mañana
# 5  2013-01-01 05:00:00       0            5           1    1         mañana
# 6  2013-01-01 06:00:00       0            6           1    1         mañana
# 7  2013-01-01 06:00:00       0            6           1    1         mañana
# 8  2013-01-01 06:00:00       0            6           1    1         mañana
# 9  2013-01-01 06:00:00       0            6           1    1         mañana
#
#    aerolinea origen destino  distancia_km
# id
# 0         UA    EWR     IAH    2253.07600
# 1         UA    LGA     IAH    2278.82544
# 2         AA    JFK     MIA    1752.57126
# 3         B6    JFK     BQN    2536.31984
# 4         DL    LGA     ATL    1226.31708
# 5         UA    EWR     ORD    1157.11546
# 6         B6    EWR     FLL    1713.94710
# 7         EV    LGA     IAD     368.53886
# 8         B6    JFK     MCO    1519.21696
# 9         AA    LGA     ORD    1179.64622

# %%
df_copia["distancia_km"] = df_copia["distancia_km"].round(2)
df_copia = df_copia.drop(columns=["distancia_millas"])

# %%
df_copia.head(10)
# Out:
#     retraso_salida_min aerolinea origen destino  fecha_hora_partida  target  \
# id
# 0                  2.0        UA    EWR     IAH 2013-01-01 05:00:00       0
# 1                  4.0        UA    LGA     IAH 2013-01-01 05:00:00       0
# 2                  2.0        AA    JFK     MIA 2013-01-01 05:00:00       0
# 3                 -1.0        B6    JFK     BQN 2013-01-01 05:00:00       0
# 4                 -6.0        DL    LGA     ATL 2013-01-01 06:00:00       0
# 5                 -4.0        UA    EWR     ORD 2013-01-01 05:00:00       0
# 6                 -5.0        B6    EWR     FLL 2013-01-01 06:00:00       0
# 7                 -3.0        EV    LGA     IAD 2013-01-01 06:00:00       0
# 8                 -3.0        B6    JFK     MCO 2013-01-01 06:00:00       0
# 9                 -2.0        AA    LGA     ORD 2013-01-01 06:00:00       0
#
#     hora_salida  dia_semana  mes franja_horaria aerolinea origen destino  \
# id
# 0             5           1    1         mañana        UA    EWR     IAH
# 1             5           1    1         mañana        UA    LGA     IAH
# 2             5           1    1         mañana        AA    JFK     MIA
# 3             5           1    1         mañana        B6    JFK     BQN
# 4             6           1    1         mañana        DL    LGA     ATL
# 5             5           1    1         mañana        UA    EWR     ORD
# 6             6           1    1         mañana        B6    EWR     FLL
# 7             6           1    1         mañana        EV    LGA     IAD
# 8             6           1    1         mañana        B6    JFK     MCO
# 9             6           1    1         mañana        AA    LGA     ORD
#
#     distancia_km
# id
# 0        2253.08
# 1        2278.83
# 2        1752.57
# 3        2536.32
# 4        1226.32
# 5        1157.12
# 6        1713.95
# 7         368.54
# 8        1519.22
# 9        1179.65

# %% [markdown]
# # Chequeo final de las columnas
#
# Se observa que al renombrar las columnas estas se duplicaron (aerolinea, origen y destino) por lo que se procede a eliminarlas.

# %%
df_copia = df_copia.loc[:, ~df_copia.columns.duplicated()]

# %%
df_copia.sample(10)
# Out:
#         retraso_salida_min aerolinea origen destino  fecha_hora_partida  \
# id
# 295813                -5.0        UA    LGA     DEN 2013-08-17 15:00:00
# 268736                32.0        DL    LGA     FLL 2013-07-20 11:00:00
# 253668                -4.0        B6    JFK     LAX 2013-07-04 12:00:00
# 322381                 0.0        9E    JFK     BNA 2013-09-15 15:00:00
# 19312                 -6.0        UA    EWR     IAH 2013-01-23 08:00:00
# 280463               204.0        AA    EWR     DFW 2013-08-01 13:00:00
# 300150                -7.0        B6    JFK     BUF 2013-08-22 07:00:00
# 95744                 33.0        AA    LGA     MIA 2013-12-14 13:00:00
# 247542               143.0        EV    EWR     MSP 2013-06-27 17:00:00
# 195736                -2.0        DL    LGA     ATL 2013-05-03 12:00:00
#
#         target  hora_salida  dia_semana  mes franja_horaria  distancia_km
# id
# 295813       0           15           5    8          tarde       2607.13
# 268736       1           11           5    7         mañana       1731.65
# 253668       0           12           3    7          tarde       3983.12
# 322381       0           15           6    9          tarde       1231.15
# 19312        0            8           2    1         mañana       2253.08
# 280463       1           13           3    8          tarde       2208.01
# 300150       0            7           3    8         mañana        484.41
# 95744        1           13           5   12          tarde       1763.84
# 247542       1           17           3    6          tarde       1622.21
# 195736       0           12           4    5          tarde       1226.32

# %% [markdown]
# # 📘 | Diccionario de Datos post-limpieza
#
# | **Nombre**               | **Descripción**                                                        |
# |--------------------------|------------------------------------------------------------------------|
# | `retraso_salida_min`              | Minutos de retraso en la salida real del vuelo respecto a la hora programada.                         |
# | `aerolinea`                   | Código de la aerolínea que opera el vuelo, normalmente de dos letras.                                    |
# | `origen`                  | Código IATA de tres letras del aeropuerto desde el cual despega el vuelo.                                         |
# | `destino`           | Codigo de tres letras del aeropuerto al que llega el vuelo.                   |
# | `fecha_hora_partida`                 | Fecha y hora de programadas del vuelo combinadas en un solo campo de tipo date-time.                                   |
# | `hora_salida`              | Hora del día (0–23) derivada de fecha_hora_partida para el despegue.                                 |
# | `dia_semana`                  | Dia de la semana del vuelo, donde 0 = Lunes y 6 = Domingo.                                         |
# | `mes`            | Mes del año en que se programa el vuelo, valor desde 1 a 12.                                    |
# | `franja_horaria`           | Categoría de tiempo del día: mañana, tarde o noche según la hora de salida.                             |
# | `distancia_km`         | Distancia entre aeropuertos medida en kilómetros, convertida desde distancia_millas.                                |
# | `target`          | Variable objetivo: 0 = vuelo puntual, 1 = vuelo retrasado en la salida.
